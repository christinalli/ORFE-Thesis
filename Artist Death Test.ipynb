# %%
import os
import time
import random
import pandas as pd
import requests

# %%
# input/output files
INPUT_CSV = "artists_unique.csv"
PARTIAL_CSV = "artist_vitals_lookup_partial.csv"
FINAL_CSV = "artist_vitals_lookup.csv"

# checkpointing
SAVE_EVERY_SECONDS = 120

# settings
SLEEP_BASE = 0.15   
SLEEP_JITTER = 0.15 
LIMIT_N = None

# %%
SEARCH_URL = "https://www.wikidata.org/w/api.php"
SPARQL_URL = "https://query.wikidata.org/sparql"

HEADERS = {
    "Accept": "application/sparql-results+json",
    "User-Agent": "artist-vitals-research/1.0 (contact: you@example.com)"
}

def wikidata_search_qid(name: str, limit: int = 1) -> str | None:
    params = {
        "action": "wbsearchentities",
        "search": name,
        "language": "en",
        "format": "json",
        "limit": limit,
        "type": "item",
    }
    try:
        r = session.get(
            SEARCH_URL,
            params=params,
            headers={"User-Agent": HEADERS["User-Agent"]},
            timeout=30
        )
        if r.status_code != 200:
            return None
        data = r.json()
        hits = data.get("search", [])
        return hits[0]["id"] if hits else None
    except Exception:
        return None

session = requests.Session()

def death_date_from_qid(qid: str, max_retries: int = 5) -> pd.Timestamp | None:
    query = f"""
    SELECT ?death WHERE {{
      wd:{qid} wdt:P570 ?death .
    }} LIMIT 1
    """

    for attempt in range(max_retries):
        try:
            r = session.get(
                SPARQL_URL,
                params={"query": query},
                headers=HEADERS,
                timeout=40
            )

            if r.status_code in (429, 500, 502, 503, 504):
                # cap the backoff so one bad artist doesn't wreck averages
                time.sleep(min(2 ** attempt, 5) + random.random())
                continue

            if r.status_code != 200:
                return None

            data = r.json()
            bindings = data.get("results", {}).get("bindings", [])
            if not bindings:
                return None

            death_str = bindings[0]["death"]["value"]
            death_ts = pd.to_datetime(death_str, errors="coerce", utc=True)
            if pd.isna(death_ts):
                return None
            return death_ts.tz_convert(None)

        except requests.exceptions.RequestException:
            time.sleep(min(2 ** attempt, 5) + random.random())
            continue
        except Exception:
            return None

    return None


def get_vitals(name: str, qid_cache: dict, death_cache: dict) -> tuple[str | None, str, pd.Timestamp | None]:
    """
    Returns (qid, vital_status, death_date)
      - vital_status: "Dead" if death_date exists, else "Alive/Unknown"
    """
    if name in qid_cache:
        qid = qid_cache[name]
    else:
        qid = wikidata_search_qid(name)
        qid_cache[name] = qid

    if not qid:
        return None, "Alive/Unknown", None

    if qid in death_cache:
        death_dt = death_cache[qid]
    else:
        death_dt = death_date_from_qid(qid)
        death_cache[qid] = death_dt

    if death_dt is not None:
        return qid, "Dead", death_dt
    return qid, "Alive/Unknown", None

# %%
# load names
artists = pd.read_csv(INPUT_CSV)

if "artist_name" not in artists.columns:
    raise ValueError("INPUT_CSV must contain a column named 'artist_name'")

artists = artists.dropna(subset=["artist_name"])
artists["artist_name"] = artists["artist_name"].astype(str).str.strip()
artists = artists.drop_duplicates(subset=["artist_name"]).reset_index(drop=True)

if LIMIT_N is not None:
    artists = artists.head(LIMIT_N).reset_index(drop=True)

names = artists["artist_name"].tolist()
print(f"Unique names to process: {len(names):,}")
# Out:
# Unique names to process: 307,286

# %%
# resume support
file_exists = os.path.exists(PARTIAL_CSV)
if file_exists:
    done = pd.read_csv(PARTIAL_CSV)
    done["artist_name"] = done["artist_name"].astype(str)
    done_set = set(done["artist_name"])
    print(f"Resuming: already have {len(done_set):,} artists")
else:
    done_set = set()
    print("Starting fresh")

qid_cache = {}    # artist_name -> QID or None
death_cache = {}  # QID -> Timestamp or None

rows = []
processed_new = 0
start = time.time()
last_save = time.time()

# for "recent" speed measurement
recent_processed = 0
recent_start = time.time()

for name in names:
    if name in done_set:
        continue

    qid, vital_status, death_dt = get_vitals(name, qid_cache, death_cache)

    rows.append({
        "artist_name": name,
        "qid": qid,
        "vital_status": vital_status,
        "death_date": death_dt  # Timestamp or None
    })

    done_set.add(name)
    processed_new += 1
    recent_processed += 1

    # pacing
    time.sleep(SLEEP_BASE + random.random() * SLEEP_JITTER)

    # time-based checkpoint (APPEND instead of rewrite)
    if rows and (time.time() - last_save) >= SAVE_EVERY_SECONDS:
        out = pd.DataFrame(rows)

        t0 = time.time()
        out.to_csv(
            PARTIAL_CSV,
            mode="a",
            header=not os.path.exists(PARTIAL_CSV),
            index=False
        )
        save_secs = time.time() - t0

        rows = []
        last_save = time.time()

        elapsed = time.time() - start
        overall_sec_per = elapsed / processed_new if processed_new else float("inf")

        recent_elapsed = time.time() - recent_start
        recent_sec_per = recent_elapsed / max(recent_processed, 1)

        print(
            f"Checkpoint saved: total≈{len(done_set):,} | "
            f"recent={recent_sec_per:.2f} sec/artist | "
            f"overall={overall_sec_per:.2f} sec/artist | "
            f"save={save_secs:.2f}s"
        )

        # reset recent window
        recent_processed = 0
        recent_start = time.time()

# final flush (append remaining)
if rows:
    out = pd.DataFrame(rows)
    out.to_csv(
        PARTIAL_CSV,
        mode="a",
        header=not os.path.exists(PARTIAL_CSV),
        index=False
    )

# read partial, dedupe, save final
done = pd.read_csv(PARTIAL_CSV)
done["artist_name"] = done["artist_name"].astype(str).str.strip()
done = done.drop_duplicates(subset=["artist_name"], keep="last")

# ensure death_date is parsed cleanly
done["death_date"] = pd.to_datetime(done["death_date"], errors="coerce")

done.to_csv(FINAL_CSV, index=False)
print(f"Saved {len(done):,} rows to {FINAL_CSV}")
# Out:
# Resuming: already have 20,799 artists
# Checkpoint saved: total≈20,893 | recent=1.29 sec/artist | overall=1.29 sec/artist | save=0.00s
# Checkpoint saved: total≈21,001 | recent=1.11 sec/artist | overall=1.19 sec/artist | save=0.01s
# Checkpoint saved: total≈21,226 | recent=0.54 sec/artist | overall=0.85 sec/artist | save=0.02s
# Checkpoint saved: total≈21,458 | recent=0.52 sec/artist | overall=0.73 sec/artist | save=0.01s
# Checkpoint saved: total≈21,681 | recent=0.54 sec/artist | overall=0.68 sec/artist | save=0.01s
# Checkpoint saved: total≈21,913 | recent=0.52 sec/artist | overall=0.65 sec/artist | save=0.01s
# Checkpoint saved: total≈22,144 | recent=0.52 sec/artist | overall=0.63 sec/artist | save=0.01s
# Checkpoint saved: total≈22,343 | recent=0.61 sec/artist | overall=0.62 sec/artist | save=0.01s
# Checkpoint saved: total≈22,544 | recent=0.60 sec/artist | overall=0.62 sec/artist | save=0.01s
# Checkpoint saved: total≈22,743 | recent=0.61 sec/artist | overall=0.62 sec/artist | save=0.01s
# Checkpoint saved: total≈22,941 | recent=0.61 sec/artist | overall=0.62 sec/artist | save=0.01s
# Checkpoint saved: total≈23,146 | recent=0.59 sec/artist | overall=0.62 sec/artist | save=0.01s
# Checkpoint saved: total≈23,338 | recent=0.63 sec/artist | overall=0.62 sec/artist | save=0.02s
# Checkpoint saved: total≈23,539 | recent=0.60 sec/artist | overall=0.62 sec/artist | save=0.00s
# Checkpoint saved: total≈23,772 | recent=0.52 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈24,001 | recent=0.53 sec/artist | overall=0.60 sec/artist | save=0.01s
# Checkpoint saved: total≈24,196 | recent=0.62 sec/artist | overall=0.60 sec/artist | save=0.01s
# Checkpoint saved: total≈24,387 | recent=0.63 sec/artist | overall=0.60 sec/artist | save=0.01s
# Checkpoint saved: total≈24,584 | recent=0.61 sec/artist | overall=0.60 sec/artist | save=0.02s
# Checkpoint saved: total≈24,783 | recent=0.60 sec/artist | overall=0.60 sec/artist | save=0.00s
# Checkpoint saved: total≈24,971 | recent=0.64 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈25,167 | recent=0.61 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈25,362 | recent=0.62 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈25,556 | recent=0.62 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈25,750 | recent=0.62 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈25,949 | recent=0.61 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈26,110 | recent=0.75 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈26,304 | recent=0.62 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈26,496 | recent=0.63 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈26,678 | recent=0.66 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈26,871 | recent=0.62 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈27,063 | recent=0.63 sec/artist | overall=0.61 sec/artist | save=0.00s
# Checkpoint saved: total≈27,256 | recent=0.62 sec/artist | overall=0.62 sec/artist | save=0.00s
# Checkpoint saved: total≈27,453 | recent=0.61 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈27,647 | recent=0.62 sec/artist | overall=0.62 sec/artist | save=0.01s
# Checkpoint saved: total≈27,863 | recent=0.56 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈28,087 | recent=0.54 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈28,321 | recent=0.51 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈28,545 | recent=0.54 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈28,746 | recent=0.60 sec/artist | overall=0.61 sec/artist | save=0.01s
# Checkpoint saved: total≈28,959 | recent=0.57 sec/artist | overall=0.60 sec/artist | save=0.00s
# Checkpoint saved: total≈29,190 | recent=0.52 sec/artist | overall=0.60 sec/artist | save=0.01s
# Checkpoint saved: total≈29,409 | recent=0.55 sec/artist | overall=0.60 sec/artist | save=0.00s
# Checkpoint saved: total≈29,638 | recent=0.52 sec/artist | overall=0.60 sec/artist | save=0.01s
# Checkpoint saved: total≈29,868 | recent=0.52 sec/artist | overall=0.60 sec/artist | save=0.01s
# Checkpoint saved: total≈30,096 | recent=0.53 sec/artist | overall=0.60 sec/artist | save=0.00s
# Checkpoint saved: total≈30,328 | recent=0.52 sec/artist | overall=0.59 sec/artist | save=0.02s
# Checkpoint saved: total≈30,556 | recent=0.53 sec/artist | overall=0.59 sec/artist | save=0.00s
# Checkpoint saved: total≈30,786 | recent=0.52 sec/artist | overall=0.59 sec/artist | save=0.00s
# Checkpoint saved: total≈31,019 | recent=0.52 sec/artist | overall=0.59 sec/artist | save=0.00s
# Checkpoint saved: total≈31,243 | recent=0.54 sec/artist | overall=0.59 sec/artist | save=0.00s
# Checkpoint saved: total≈31,475 | recent=0.52 sec/artist | overall=0.59 sec/artist | save=0.01s
# Checkpoint saved: total≈31,705 | recent=0.52 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈31,927 | recent=0.54 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈32,155 | recent=0.53 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈32,380 | recent=0.53 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈32,610 | recent=0.52 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈32,843 | recent=0.52 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈33,078 | recent=0.51 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈33,309 | recent=0.52 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈33,536 | recent=0.53 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈33,767 | recent=0.52 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈33,989 | recent=0.54 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈34,213 | recent=0.54 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈34,444 | recent=0.52 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈34,673 | recent=0.52 sec/artist | overall=0.57 sec/artist | save=0.03s
# Checkpoint saved: total≈34,891 | recent=0.55 sec/artist | overall=0.57 sec/artist | save=0.02s
# Checkpoint saved: total≈35,094 | recent=0.59 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈35,297 | recent=0.59 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈35,522 | recent=0.53 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈35,755 | recent=0.52 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈35,960 | recent=0.59 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈36,168 | recent=0.58 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈36,377 | recent=0.58 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈36,584 | recent=0.58 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈36,797 | recent=0.56 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈37,009 | recent=0.57 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈37,215 | recent=0.58 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈37,416 | recent=0.60 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈37,619 | recent=0.59 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈37,821 | recent=0.60 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈38,050 | recent=0.52 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈38,277 | recent=0.53 sec/artist | overall=0.57 sec/artist | save=0.00s
# Checkpoint saved: total≈38,506 | recent=0.53 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈38,736 | recent=0.84 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈38,848 | recent=1.08 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈39,070 | recent=0.54 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈39,269 | recent=1.30 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈39,502 | recent=0.52 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈39,744 | recent=0.50 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈39,985 | recent=0.50 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈40,223 | recent=0.51 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈40,463 | recent=0.50 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈40,703 | recent=0.50 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈40,951 | recent=0.49 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈41,147 | recent=0.61 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈41,383 | recent=0.51 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈41,627 | recent=0.49 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈41,761 | recent=0.98 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈41,999 | recent=0.51 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈42,241 | recent=0.50 sec/artist | overall=0.58 sec/artist | save=0.00s
# Checkpoint saved: total≈42,410 | recent=0.74 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈42,630 | recent=0.55 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈42,924 | recent=0.41 sec/artist | overall=0.58 sec/artist | save=0.01s
# Checkpoint saved: total≈43,217 | recent=0.41 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈43,502 | recent=0.42 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈43,795 | recent=0.41 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈44,083 | recent=0.42 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈44,377 | recent=0.41 sec/artist | overall=0.57 sec/artist | save=0.01s
# Checkpoint saved: total≈44,663 | recent=0.42 sec/artist | overall=0.56 sec/artist | save=0.01s
# Checkpoint saved: total≈44,953 | recent=0.41 sec/artist | overall=0.56 sec/artist | save=0.01s
# Checkpoint saved: total≈45,241 | recent=0.42 sec/artist | overall=0.56 sec/artist | save=0.00s
# Checkpoint saved: total≈45,534 | recent=0.41 sec/artist | overall=0.56 sec/artist | save=0.01s
# Checkpoint saved: total≈45,828 | recent=0.41 sec/artist | overall=0.56 sec/artist | save=0.01s
# Checkpoint saved: total≈46,108 | recent=0.43 sec/artist | overall=0.56 sec/artist | save=0.00s
# Checkpoint saved: total≈46,389 | recent=0.43 sec/artist | overall=0.55 sec/artist | save=0.01s
# Checkpoint saved: total≈46,676 | recent=0.42 sec/artist | overall=0.55 sec/artist | save=0.00s
# Checkpoint saved: total≈46,965 | recent=0.42 sec/artist | overall=0.55 sec/artist | save=0.01s
# Checkpoint saved: total≈47,257 | recent=0.41 sec/artist | overall=0.55 sec/artist | save=0.01s
# Checkpoint saved: total≈47,548 | recent=0.41 sec/artist | overall=0.55 sec/artist | save=0.00s
# Checkpoint saved: total≈47,837 | recent=0.42 sec/artist | overall=0.55 sec/artist | save=0.01s
# Checkpoint saved: total≈48,125 | recent=0.42 sec/artist | overall=0.55 sec/artist | save=0.01s
# Checkpoint saved: total≈48,416 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈48,707 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈48,995 | recent=0.42 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈49,286 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈49,581 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.00s
# Checkpoint saved: total≈49,872 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈50,167 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈50,214 | recent=3.05 sec/artist | overall=0.54 sec/artist | save=0.00s
# Checkpoint saved: total≈50,499 | recent=0.42 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈50,789 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈51,083 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈51,378 | recent=0.41 sec/artist | overall=0.54 sec/artist | save=0.01s
# Checkpoint saved: total≈51,669 | recent=0.41 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈51,961 | recent=0.41 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈52,246 | recent=0.42 sec/artist | overall=0.53 sec/artist | save=0.00s
# Checkpoint saved: total≈52,540 | recent=0.41 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈52,840 | recent=0.40 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈53,139 | recent=0.40 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈53,428 | recent=0.42 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈53,721 | recent=0.41 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈54,019 | recent=0.40 sec/artist | overall=0.53 sec/artist | save=0.01s
# Checkpoint saved: total≈54,317 | recent=0.40 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈54,611 | recent=0.41 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈54,910 | recent=0.40 sec/artist | overall=0.52 sec/artist | save=0.00s
# Checkpoint saved: total≈55,199 | recent=0.42 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈55,494 | recent=0.41 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈55,786 | recent=0.41 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈56,072 | recent=0.42 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈56,368 | recent=0.41 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈56,665 | recent=0.41 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈56,960 | recent=0.41 sec/artist | overall=0.52 sec/artist | save=0.01s
# Checkpoint saved: total≈57,259 | recent=0.40 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈57,552 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈57,845 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈58,139 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈58,433 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈58,723 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈59,018 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈59,310 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈59,603 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈59,896 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈60,191 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈60,484 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.00s
# Checkpoint saved: total≈60,779 | recent=0.41 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈61,063 | recent=0.42 sec/artist | overall=0.51 sec/artist | save=0.01s
# Checkpoint saved: total≈61,356 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈61,652 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈61,952 | recent=0.40 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈62,247 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈62,537 | recent=0.42 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈62,814 | recent=0.43 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈63,112 | recent=0.40 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈63,412 | recent=0.40 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈63,705 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.00s
# Checkpoint saved: total≈64,000 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.00s
# Checkpoint saved: total≈64,300 | recent=0.40 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈64,599 | recent=0.40 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈64,895 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈65,188 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈65,483 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈65,775 | recent=0.41 sec/artist | overall=0.50 sec/artist | save=0.01s
# Checkpoint saved: total≈66,065 | recent=0.42 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈66,359 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈66,653 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈66,944 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈67,244 | recent=0.40 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈67,537 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈67,836 | recent=0.40 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈68,135 | recent=0.40 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈68,428 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈68,716 | recent=0.42 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈69,008 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈69,310 | recent=0.40 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈69,613 | recent=0.40 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈69,908 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈70,204 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.00s
# Checkpoint saved: total≈70,501 | recent=0.40 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈70,796 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈71,084 | recent=0.42 sec/artist | overall=0.49 sec/artist | save=0.00s
# Checkpoint saved: total≈71,380 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈71,673 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈71,972 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈72,267 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈72,559 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈72,852 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈73,146 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈73,444 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈73,737 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈74,034 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈74,329 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈74,628 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈74,926 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈75,220 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈75,517 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈75,811 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈76,106 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈76,400 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈76,704 | recent=0.39 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈77,008 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈77,301 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈77,592 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈77,885 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈78,176 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈78,476 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈78,779 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈79,074 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈79,373 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈79,670 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈79,957 | recent=0.42 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈80,254 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈80,550 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈80,845 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈81,144 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈81,445 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈81,736 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈82,033 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈82,323 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈82,618 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈82,913 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈83,209 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈83,501 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈83,802 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈84,106 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈84,394 | recent=0.42 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈84,625 | recent=0.71 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈84,860 | recent=0.76 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈85,150 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈85,450 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈85,752 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈86,070 | recent=0.38 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈86,372 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈86,654 | recent=0.43 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈86,938 | recent=0.42 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈87,237 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈87,530 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈87,826 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈88,126 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈88,422 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈88,724 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈89,022 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈89,326 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈89,625 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈89,891 | recent=0.46 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈90,176 | recent=0.42 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈90,486 | recent=0.39 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈90,792 | recent=0.39 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈91,088 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈91,393 | recent=0.39 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈91,693 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈91,989 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈92,289 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈92,581 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈92,876 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈93,183 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈93,484 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈93,787 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈94,084 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈94,370 | recent=0.42 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈94,650 | recent=0.43 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈94,937 | recent=0.42 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈95,234 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈95,532 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈95,822 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈96,132 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈96,440 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈96,742 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈97,043 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈97,336 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈97,657 | recent=0.37 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈97,965 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈98,276 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈98,590 | recent=0.38 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈98,897 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈99,200 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈99,496 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈99,793 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈100,093 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈100,388 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈100,682 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈100,986 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈101,286 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈101,586 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈101,886 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈102,190 | recent=0.39 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈102,485 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈102,783 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈103,086 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈103,386 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈103,682 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈103,977 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈104,272 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈104,576 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈104,884 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈105,182 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈105,486 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈105,786 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈106,087 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈106,390 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈106,691 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈106,981 | recent=0.42 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈107,284 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈107,577 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈107,883 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈108,183 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈108,482 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈108,784 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈109,086 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈109,393 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈109,701 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈110,003 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈110,309 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈110,611 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈110,910 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈111,213 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈111,517 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈111,819 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈112,122 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈112,432 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈112,735 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈113,036 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈113,335 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈113,639 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈113,943 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈114,253 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈114,561 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈114,869 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈115,170 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈115,482 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈115,786 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈116,090 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈116,403 | recent=0.38 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈116,705 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈117,017 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈117,320 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈117,633 | recent=0.38 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈117,944 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈118,254 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.03s
# Checkpoint saved: total≈118,557 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈118,867 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈119,171 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈119,478 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈119,787 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈120,101 | recent=0.38 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈120,414 | recent=0.38 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈120,716 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈121,020 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈121,330 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈121,639 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈121,947 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈122,259 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈122,560 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈122,880 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈123,192 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈123,499 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈123,808 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈124,116 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈124,428 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈124,728 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈125,032 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈125,338 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈125,641 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈125,945 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈126,249 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈126,555 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈126,865 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈127,171 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈127,474 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈127,775 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈128,082 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈128,390 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈128,701 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈129,015 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈129,324 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈129,627 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈129,947 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈130,257 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈130,572 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈130,860 | recent=0.42 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈131,172 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈131,482 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈131,791 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈132,099 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈132,411 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈132,723 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈133,041 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈133,352 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈133,661 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈133,978 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈134,295 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈134,606 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈134,920 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈135,235 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈135,552 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈135,858 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈136,164 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈136,475 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈136,783 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈137,091 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈137,394 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈137,704 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈138,013 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈138,326 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈138,641 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈138,952 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈139,265 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈139,575 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈139,886 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈140,186 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈140,497 | recent=0.39 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈140,800 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈141,113 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈141,432 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈141,749 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈142,064 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈142,364 | recent=0.40 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈142,680 | recent=0.38 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈142,994 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈143,304 | recent=0.39 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈143,625 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈143,936 | recent=0.39 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈144,250 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈144,564 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈144,883 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈145,197 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈145,514 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈145,831 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈146,144 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈146,463 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈146,778 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈147,095 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈147,407 | recent=0.39 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈147,723 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈148,042 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈148,358 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈148,674 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈148,991 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.02s
# Checkpoint saved: total≈149,307 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈149,624 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈149,941 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈150,253 | recent=0.39 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈150,563 | recent=0.39 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈150,877 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈151,190 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈151,508 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈151,821 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈152,138 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈152,459 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈152,771 | recent=0.39 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈153,085 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈153,406 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈153,720 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈154,035 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈154,350 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈154,663 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈154,986 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈155,309 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈155,626 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈155,946 | recent=0.38 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈156,274 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈156,597 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈156,924 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈157,250 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈157,576 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈157,904 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈158,228 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈158,552 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈158,874 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈159,201 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈159,526 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈159,847 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈160,176 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈160,501 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈160,823 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈161,145 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈161,469 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈161,798 | recent=0.36 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈162,123 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈162,450 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈162,773 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈163,099 | recent=0.37 sec/artist | overall=0.43 sec/artist | save=0.01s
# ...
# Checkpoint saved: total≈255,696 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈256,007 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈256,317 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈256,625 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈256,935 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈257,248 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈257,557 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈257,874 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈258,141 | recent=0.49 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈258,357 | recent=0.59 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈258,664 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈258,978 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈259,284 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈259,482 | recent=0.61 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈259,797 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈260,112 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈260,426 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈260,737 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈261,051 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈261,358 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈261,662 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈261,963 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈262,265 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈262,571 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈262,880 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈263,196 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈263,502 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈263,813 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈264,123 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈264,433 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈264,744 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈265,058 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈265,369 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈265,679 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈265,990 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈266,294 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈266,601 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈266,912 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈267,215 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈267,515 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈267,826 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈268,135 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈268,443 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈268,753 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈269,066 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈269,379 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈269,694 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈270,004 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈270,310 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈270,622 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈270,933 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈271,246 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈271,559 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈271,873 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈272,180 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈272,484 | recent=0.40 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈272,656 | recent=0.70 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈272,966 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈273,270 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈273,580 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈273,890 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈274,199 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈274,514 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈274,828 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈275,099 | recent=0.44 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈275,408 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈275,720 | recent=0.39 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈276,033 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈276,353 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈276,667 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈276,988 | recent=0.37 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈277,305 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈277,624 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈277,941 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈278,257 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈278,571 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈278,884 | recent=0.38 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈279,201 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈279,516 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈279,830 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈280,146 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈280,464 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈280,773 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈281,084 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈281,394 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈281,708 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈282,020 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈282,336 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈282,649 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈282,946 | recent=0.41 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈283,253 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈283,562 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈283,880 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈284,192 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈284,506 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈284,818 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈285,131 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈285,451 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈285,767 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈286,084 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈286,399 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈286,716 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈287,033 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈287,354 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈287,683 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈287,997 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈288,318 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈288,630 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈288,948 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈289,268 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈289,582 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈289,901 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈290,217 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈290,533 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈290,849 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈291,154 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈291,467 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈291,784 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈292,104 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈292,425 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈292,742 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈293,060 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈293,376 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈293,693 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈294,009 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈294,329 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈294,644 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈294,969 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈295,285 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈295,603 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈295,914 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈296,229 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈296,531 | recent=0.40 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈296,846 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈297,159 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈297,468 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈297,782 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈298,092 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈298,410 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈298,738 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈299,060 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈299,396 | recent=0.36 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈299,736 | recent=0.35 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈300,069 | recent=0.36 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈300,416 | recent=0.35 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈300,748 | recent=0.36 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈301,077 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈301,418 | recent=0.35 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈301,764 | recent=0.35 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈302,097 | recent=0.36 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈302,422 | recent=0.37 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈302,727 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈303,028 | recent=0.40 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈303,346 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈303,666 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈303,980 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈304,287 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈304,603 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈304,918 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈305,225 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈305,534 | recent=0.39 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈305,851 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈306,164 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈306,483 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈306,800 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈307,116 | recent=0.38 sec/artist | overall=0.40 sec/artist | save=0.00s
# Saved 307,286 rows to artist_vitals_lookup.csv
