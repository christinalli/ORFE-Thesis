# %%
import requests
import time
import os
import random
import pandas as pd

# %%
# files
INPUT_CSV = "artists_unique.csv"
PARTIAL_CSV = "artist_gender_lookup_partial.csv"
FINAL_CSV = "artist_gender_lookup.csv"

# checkpointing 
SAVE_EVERY_SECONDS = 120 

# settings (pacing)
SLEEP_SEARCH_BASE = 0.03
SLEEP_SPARQL_BASE = 0.08
JITTER = 0.05
LIMIT_N = None

SEARCH_URL = "https://www.wikidata.org/w/api.php"
SPARQL_URL = "https://query.wikidata.org/sparql"

HEADERS = {
    "Accept": "application/sparql-results+json",
    "User-Agent": "artist-gender-research/1.0 (contact: you@example.com)"
}

# persistent HTTP session 
session = requests.Session()

MALE_QID = "Q6581097"
FEMALE_QID = "Q6581072"

# caches
qid_cache = {}      # name -> QID or None
gender_cache = {}   # QID -> "Male"/"Female"/None

# %%
# functions
def wikidata_search_qid(name: str, limit: int = 1, max_retries: int = 4) -> str | None:
    """Return top Wikidata QID for a name using the Wikidata search API."""
    params = {
        "action": "wbsearchentities",
        "search": name,
        "language": "en",
        "format": "json",
        "limit": limit,
        "type": "item",
    }

    for attempt in range(max_retries):
        try:
            r = session.get(
                SEARCH_URL,
                params=params,
                headers={"User-Agent": HEADERS["User-Agent"]},
                timeout=30
            )

            if r.status_code in (429, 500, 502, 503, 504):
                time.sleep(min(2 ** attempt, 5) + random.random())
                continue

            if r.status_code != 200:
                return None

            data = r.json()
            hits = data.get("search", [])
            return hits[0]["id"] if hits else None

        except requests.exceptions.RequestException:
            time.sleep(min(2 ** attempt, 5) + random.random())
            continue
        except Exception:
            return None

    return None

def gender_from_qid_fast(qid: str, max_retries: int = 5) -> str | None:
    """
    Returns "Male", "Female", or None using P21.
    Uses capped backoff to avoid 10s+ stalls per artist.
    """
    if qid in gender_cache:
        return gender_cache[qid]

    query = f"""
    SELECT ?gender WHERE {{
      wd:{qid} wdt:P21 ?gender .
    }} LIMIT 1
    """

    for attempt in range(max_retries):
        try:
            r = session.get(
                SPARQL_URL,
                params={"query": query},
                headers=HEADERS,
                timeout=40
            )

            if r.status_code in (429, 500, 502, 503, 504):
                time.sleep(min(2 ** attempt, 5) + random.random())
                continue

            if r.status_code != 200:
                gender_cache[qid] = None
                return None

            data = r.json()
            bindings = data.get("results", {}).get("bindings", [])
            if not bindings:
                gender_cache[qid] = None
                return None

            gender_uri = bindings[0]["gender"]["value"]
            if gender_uri.endswith(MALE_QID):
                gender_cache[qid] = "Male"
                return "Male"
            if gender_uri.endswith(FEMALE_QID):
                gender_cache[qid] = "Female"
                return "Female"

            gender_cache[qid] = None
            return None

        except requests.exceptions.RequestException:
            time.sleep(min(2 ** attempt, 5) + random.random())
            continue
        except Exception:
            gender_cache[qid] = None
            return None

    gender_cache[qid] = None
    return None

def get_gender_wikidata_robust_fast(name: str) -> str | None:
    """
    name -> QID via search API -> gender via SPARQL
    """
    if name in qid_cache:
        qid = qid_cache[name]
    else:
        qid = wikidata_search_qid(name)
        qid_cache[name] = qid

    if not qid:
        return None

    return gender_from_qid_fast(qid)

# %%
# load names
artists = pd.read_csv(INPUT_CSV)

if "artist_name" not in artists.columns:
    raise ValueError("INPUT_CSV must contain a column named 'artist_name'")

artists = artists.dropna(subset=["artist_name"])
artists["artist_name"] = artists["artist_name"].astype(str).str.strip()
artists = artists.drop_duplicates(subset=["artist_name"]).reset_index(drop=True)

if LIMIT_N is not None:
    artists = artists.head(LIMIT_N).reset_index(drop=True)

names = artists["artist_name"].tolist()
print(f"Unique names to process: {len(names):,}")
# Out:
# Unique names to process: 307,286

# %%
# resume support
if os.path.exists(PARTIAL_CSV):
    done = pd.read_csv(PARTIAL_CSV)
    done["artist_name"] = done["artist_name"].astype(str).str.strip()
    done_set = set(done["artist_name"])
    print(f"Resuming: already have {len(done_set):,} artists")
else:
    done_set = set()
    print("Starting fresh")

rows = []
processed_new = 0
start = time.time()
last_save = time.time()

# recent speed window
recent_processed = 0
recent_start = time.time()

for name in names:
    if name in done_set:
        continue

    g = get_gender_wikidata_robust_fast(name)

    rows.append({"artist_name": name, "artist_gender": g})
    done_set.add(name)
    processed_new += 1
    recent_processed += 1

    # pacing
    time.sleep(SLEEP_SEARCH_BASE + SLEEP_SPARQL_BASE + random.random() * JITTER)

    # time-based checkpoint (append only new rows)
    if rows and (time.time() - last_save) >= SAVE_EVERY_SECONDS:
        out = pd.DataFrame(rows)

        t0 = time.time()
        out.to_csv(
            PARTIAL_CSV,
            mode="a",
            header=not os.path.exists(PARTIAL_CSV),
            index=False
        )
        save_secs = time.time() - t0

        rows = []
        last_save = time.time()

        elapsed = time.time() - start
        overall_sec_per = elapsed / processed_new if processed_new else float("inf")

        recent_elapsed = time.time() - recent_start
        recent_sec_per = recent_elapsed / max(recent_processed, 1)

        print(
            f"Checkpoint saved: total≈{len(done_set):,} | "
            f"recent={recent_sec_per:.2f} sec/artist | "
            f"overall={overall_sec_per:.2f} sec/artist | "
            f"save={save_secs:.2f}s"
        )

        recent_processed = 0
        recent_start = time.time()

# final flush (append remaining)
if rows:
    out = pd.DataFrame(rows)
    out.to_csv(
        PARTIAL_CSV,
        mode="a",
        header=not os.path.exists(PARTIAL_CSV),
        index=False
    )

# read partial once, dedupe, save final
done = pd.read_csv(PARTIAL_CSV)
done["artist_name"] = done["artist_name"].astype(str).str.strip()
done = done.drop_duplicates(subset=["artist_name"], keep="last")

done.to_csv(FINAL_CSV, index=False)
print(f"Saved {len(done):,} rows to {FINAL_CSV}")
# Out:
# Resuming: already have 22,000 artists
# Checkpoint saved: total≈22,284 | recent=0.42 sec/artist | overall=0.42 sec/artist | save=0.01s
# Checkpoint saved: total≈22,545 | recent=0.46 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈22,793 | recent=0.49 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈23,039 | recent=0.49 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈23,278 | recent=0.50 sec/artist | overall=0.47 sec/artist | save=0.02s
# Checkpoint saved: total≈23,532 | recent=0.47 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈23,776 | recent=0.49 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈24,014 | recent=0.51 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈24,294 | recent=0.43 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈24,589 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈24,855 | recent=0.45 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈25,081 | recent=0.53 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈25,325 | recent=0.49 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈25,569 | recent=0.49 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈25,809 | recent=0.50 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈26,049 | recent=0.50 sec/artist | overall=0.48 sec/artist | save=0.00s
# Checkpoint saved: total≈26,300 | recent=0.48 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈26,539 | recent=0.50 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈26,785 | recent=0.49 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈27,029 | recent=0.49 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈27,254 | recent=0.54 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈27,466 | recent=0.57 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈27,702 | recent=0.51 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈27,928 | recent=0.53 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈28,165 | recent=0.51 sec/artist | overall=0.49 sec/artist | save=0.00s
# Checkpoint saved: total≈28,408 | recent=0.50 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈28,650 | recent=0.50 sec/artist | overall=0.49 sec/artist | save=0.02s
# Checkpoint saved: total≈28,886 | recent=0.51 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈29,123 | recent=0.51 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈29,377 | recent=0.47 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈29,669 | recent=0.41 sec/artist | overall=0.49 sec/artist | save=0.01s
# Checkpoint saved: total≈29,968 | recent=0.40 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈30,261 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.00s
# Checkpoint saved: total≈30,544 | recent=0.43 sec/artist | overall=0.48 sec/artist | save=0.00s
# Checkpoint saved: total≈30,791 | recent=0.49 sec/artist | overall=0.48 sec/artist | save=0.01s
# Checkpoint saved: total≈31,082 | recent=0.41 sec/artist | overall=0.48 sec/artist | save=0.00s
# Checkpoint saved: total≈31,365 | recent=0.43 sec/artist | overall=0.48 sec/artist | save=0.00s
# Checkpoint saved: total≈31,662 | recent=0.40 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈31,950 | recent=0.42 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈32,242 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈32,535 | recent=0.41 sec/artist | overall=0.47 sec/artist | save=0.01s
# Checkpoint saved: total≈32,841 | recent=0.39 sec/artist | overall=0.47 sec/artist | save=0.00s
# Checkpoint saved: total≈33,141 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈33,438 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈33,734 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈34,020 | recent=0.42 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈34,313 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈34,606 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈34,894 | recent=0.42 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈35,186 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈35,486 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈35,780 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈36,069 | recent=0.42 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈36,367 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈36,675 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈36,981 | recent=0.39 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈37,273 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈37,562 | recent=0.42 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈37,851 | recent=0.42 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈38,142 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈38,435 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈38,698 | recent=0.46 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈38,950 | recent=0.48 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈39,215 | recent=0.45 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈39,494 | recent=0.43 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈39,765 | recent=0.44 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈40,022 | recent=0.47 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈40,270 | recent=0.49 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈40,519 | recent=0.48 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈40,773 | recent=0.47 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈41,023 | recent=0.48 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈41,279 | recent=0.47 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈41,530 | recent=0.48 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈41,786 | recent=0.47 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈42,035 | recent=0.48 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈42,312 | recent=0.43 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈42,604 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈42,908 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈43,207 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈43,307 | recent=1.34 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈43,482 | recent=0.69 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈43,782 | recent=0.40 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈44,005 | recent=0.99 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈44,245 | recent=0.50 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈44,542 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈44,841 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈45,138 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈45,442 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈45,737 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈46,033 | recent=0.41 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈46,271 | recent=0.51 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈46,560 | recent=0.42 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈46,852 | recent=0.41 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈47,033 | recent=1.11 sec/artist | overall=0.46 sec/artist | save=0.00s
# Checkpoint saved: total≈47,332 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈47,631 | recent=0.40 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈47,768 | recent=0.88 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈48,141 | recent=0.32 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈48,524 | recent=0.31 sec/artist | overall=0.46 sec/artist | save=0.01s
# Checkpoint saved: total≈48,886 | recent=0.33 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈49,258 | recent=0.32 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈49,633 | recent=0.32 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈50,004 | recent=0.32 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈50,373 | recent=0.33 sec/artist | overall=0.45 sec/artist | save=0.00s
# Checkpoint saved: total≈50,739 | recent=0.33 sec/artist | overall=0.45 sec/artist | save=0.01s
# Checkpoint saved: total≈51,114 | recent=0.32 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈51,489 | recent=0.32 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈51,860 | recent=0.32 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈52,216 | recent=0.34 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈52,572 | recent=0.34 sec/artist | overall=0.44 sec/artist | save=0.00s
# Checkpoint saved: total≈52,947 | recent=0.32 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈53,319 | recent=0.32 sec/artist | overall=0.44 sec/artist | save=0.01s
# Checkpoint saved: total≈53,697 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈54,074 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈54,451 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈54,826 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈55,195 | recent=0.33 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈55,569 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈55,937 | recent=0.33 sec/artist | overall=0.43 sec/artist | save=0.00s
# Checkpoint saved: total≈56,316 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈56,688 | recent=0.32 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈57,065 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈57,446 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.01s
# Checkpoint saved: total≈57,760 | recent=0.71 sec/artist | overall=0.43 sec/artist | save=0.01s
# Checkpoint saved: total≈58,134 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈58,510 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈58,887 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈59,265 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈59,646 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈60,024 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.01s
# Checkpoint saved: total≈60,404 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈60,779 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.01s
# Checkpoint saved: total≈61,150 | recent=0.32 sec/artist | overall=0.42 sec/artist | save=0.01s
# Checkpoint saved: total≈61,535 | recent=0.31 sec/artist | overall=0.42 sec/artist | save=0.00s
# Checkpoint saved: total≈61,924 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈62,306 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈62,689 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈63,077 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈63,463 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈63,850 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.00s
# Checkpoint saved: total≈64,232 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈64,614 | recent=0.31 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈64,993 | recent=0.32 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈65,337 | recent=0.35 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈65,716 | recent=0.32 sec/artist | overall=0.41 sec/artist | save=0.01s
# Checkpoint saved: total≈66,094 | recent=0.32 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈66,470 | recent=0.32 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈66,861 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈67,244 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈67,627 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈68,012 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈68,404 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈68,782 | recent=0.32 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈69,170 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈69,560 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈69,946 | recent=0.31 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈70,340 | recent=0.30 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈70,719 | recent=0.32 sec/artist | overall=0.40 sec/artist | save=0.01s
# Checkpoint saved: total≈71,090 | recent=0.32 sec/artist | overall=0.40 sec/artist | save=0.00s
# Checkpoint saved: total≈71,468 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈71,848 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈72,224 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈72,602 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈72,979 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈73,362 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈73,734 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈74,099 | recent=0.33 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈74,482 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈74,871 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈75,257 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈75,642 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈76,024 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.00s
# Checkpoint saved: total≈76,390 | recent=0.33 sec/artist | overall=0.39 sec/artist | save=0.00s
# Checkpoint saved: total≈76,783 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.00s
# Checkpoint saved: total≈77,172 | recent=0.31 sec/artist | overall=0.39 sec/artist | save=0.00s
# Checkpoint saved: total≈77,544 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.00s
# Checkpoint saved: total≈77,920 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈78,291 | recent=0.32 sec/artist | overall=0.39 sec/artist | save=0.01s
# Checkpoint saved: total≈78,682 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈79,075 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈79,458 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈79,845 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈80,234 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈80,610 | recent=0.32 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈80,991 | recent=0.32 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈81,369 | recent=0.32 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈81,749 | recent=0.32 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈82,137 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈82,514 | recent=0.32 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈82,895 | recent=0.32 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈83,277 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈83,663 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈84,048 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈84,435 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈84,824 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈85,211 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈85,612 | recent=0.30 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈86,028 | recent=0.29 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈86,435 | recent=0.30 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈86,819 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.01s
# Checkpoint saved: total≈87,207 | recent=0.31 sec/artist | overall=0.38 sec/artist | save=0.00s
# Checkpoint saved: total≈87,592 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈87,982 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈88,373 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈88,771 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈89,163 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈89,558 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈89,946 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈90,333 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈90,739 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈91,133 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈91,518 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈91,905 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈92,292 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈92,683 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈93,081 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈93,472 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈93,867 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈94,256 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈94,643 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈95,032 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈95,420 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.00s
# Checkpoint saved: total≈95,810 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈96,208 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈96,593 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈96,990 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈97,380 | recent=0.31 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈97,778 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈98,174 | recent=0.30 sec/artist | overall=0.37 sec/artist | save=0.01s
# Checkpoint saved: total≈98,574 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈98,964 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈99,353 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈99,742 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈100,139 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈100,521 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈100,913 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈101,302 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈101,694 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈102,073 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈102,448 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈102,816 | recent=0.48 sec/artist | overall=0.36 sec/artist | save=0.02s
# Checkpoint saved: total≈103,146 | recent=0.55 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈103,521 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈103,904 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈104,276 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈104,655 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈105,045 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈105,413 | recent=0.33 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈105,795 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈106,177 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈106,554 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈106,948 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈107,347 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈107,729 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈108,121 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈108,511 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈108,892 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈109,287 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈109,668 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈110,037 | recent=0.33 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈110,441 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈110,839 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈111,230 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈111,627 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈112,015 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈112,409 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈112,798 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈113,183 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈113,569 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈113,963 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈114,369 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈114,766 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈115,165 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈115,555 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈115,932 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈116,313 | recent=0.32 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈116,705 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.01s
# Checkpoint saved: total≈117,100 | recent=0.30 sec/artist | overall=0.36 sec/artist | save=0.03s
# Checkpoint saved: total≈117,490 | recent=0.31 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈117,904 | recent=0.29 sec/artist | overall=0.36 sec/artist | save=0.00s
# Checkpoint saved: total≈118,315 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈118,708 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈119,110 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈119,509 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈119,915 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈120,325 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈120,737 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈121,139 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈121,549 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈121,949 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈122,340 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈122,739 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈123,139 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈123,528 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈123,927 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈124,323 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈124,704 | recent=0.32 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈125,089 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈125,479 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈125,870 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈126,261 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈126,655 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈127,051 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈127,438 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈127,806 | recent=0.33 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈128,194 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈128,590 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈128,993 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈129,395 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈129,795 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈130,200 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈130,601 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈131,014 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈131,412 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈131,817 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈132,211 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈132,611 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈133,024 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈133,425 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈133,825 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈134,239 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈134,645 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈135,056 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈135,468 | recent=0.29 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈135,866 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈136,261 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈136,662 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈137,054 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈137,445 | recent=0.31 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈137,845 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈138,249 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈138,650 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈139,052 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈139,453 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.00s
# Checkpoint saved: total≈139,857 | recent=0.30 sec/artist | overall=0.35 sec/artist | save=0.01s
# Checkpoint saved: total≈140,259 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈140,660 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈141,060 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈141,466 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈141,874 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈142,270 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈142,677 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈143,075 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈143,476 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈143,876 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈144,273 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈144,669 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈145,079 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈145,482 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈145,882 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈146,284 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈146,688 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈147,093 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈147,491 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈147,892 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈148,299 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈148,705 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈149,104 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈149,509 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈149,908 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈150,315 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈150,715 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈151,121 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.03s
# Checkpoint saved: total≈151,523 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈151,921 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈152,323 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈152,724 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈153,123 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈153,529 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈153,935 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈154,334 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈154,733 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈155,137 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈155,544 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈155,953 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈156,361 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈156,756 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈157,159 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈157,560 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈157,965 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈158,369 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈158,771 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈159,175 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈159,589 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈159,988 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈160,401 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈160,803 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈161,204 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈161,607 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈162,015 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈162,417 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈162,820 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈163,235 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈163,631 | recent=0.32 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈164,025 | recent=0.31 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈164,432 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈164,841 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈165,239 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈165,637 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈166,030 | recent=0.31 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈166,439 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈166,849 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈167,251 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈167,656 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈168,066 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈168,469 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈168,873 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈169,273 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈169,680 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.01s
# Checkpoint saved: total≈170,086 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈170,494 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈170,900 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈171,313 | recent=0.29 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈171,718 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈172,114 | recent=0.30 sec/artist | overall=0.34 sec/artist | save=0.00s
# Checkpoint saved: total≈172,515 | recent=0.30 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈172,928 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈173,333 | recent=0.30 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈173,753 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈174,158 | recent=0.30 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈174,571 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈174,978 | recent=0.30 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈175,389 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈175,769 | recent=0.32 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈176,183 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈176,588 | recent=0.30 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈176,996 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈177,398 | recent=0.30 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈177,812 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈178,236 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈178,665 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈179,089 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈179,515 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈179,935 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈180,359 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈180,785 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈181,210 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈181,624 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈182,048 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈182,476 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈182,897 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈183,322 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈183,747 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈184,173 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈184,593 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈185,012 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈185,438 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈185,867 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈186,292 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈186,716 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈187,137 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈187,560 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈187,983 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈188,402 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈188,829 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈189,255 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈189,682 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈190,105 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈190,525 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈190,945 | recent=0.29 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈191,380 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈191,811 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈192,239 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈192,674 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈193,107 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈193,531 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈193,961 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈194,396 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈194,828 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈195,211 | recent=0.31 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈195,638 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈196,076 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈196,507 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈196,949 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈197,392 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈197,834 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈198,284 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈198,727 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈199,171 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈199,616 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈200,054 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈200,498 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈200,942 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈201,368 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈201,793 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈202,230 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈202,659 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈203,095 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈203,529 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈203,967 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈204,403 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.01s
# Checkpoint saved: total≈204,827 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈205,259 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈205,704 | recent=0.27 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈206,128 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈206,561 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈206,994 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈207,422 | recent=0.28 sec/artist | overall=0.33 sec/artist | save=0.00s
# Checkpoint saved: total≈207,847 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈208,279 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈208,719 | recent=0.27 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈209,151 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# ...
# Checkpoint saved: total≈236,886 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈237,293 | recent=0.30 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈237,708 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈238,119 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈238,534 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈238,946 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈239,362 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.02s
# Checkpoint saved: total≈239,773 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈240,188 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈240,607 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈241,023 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈241,438 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈241,856 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈242,275 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈242,694 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈243,113 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈243,531 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈243,949 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈244,367 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈244,771 | recent=0.30 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈245,178 | recent=0.30 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈245,583 | recent=0.30 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈245,999 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈246,418 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈246,834 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈247,249 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈247,668 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈248,081 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈248,483 | recent=0.30 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈248,696 | recent=0.56 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈249,110 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈249,524 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈249,938 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈250,351 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈250,774 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈251,197 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈251,623 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈252,038 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈252,454 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈252,882 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈253,294 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.04s
# Checkpoint saved: total≈253,718 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈254,140 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈254,563 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈254,992 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈255,415 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈255,842 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈256,272 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈256,697 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈257,125 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈257,546 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈257,952 | recent=0.30 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈258,382 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈258,818 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈259,251 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈259,682 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈260,102 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈260,526 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈260,960 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈261,388 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈261,816 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈262,237 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈262,660 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈263,095 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈263,529 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈263,958 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈264,389 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈264,814 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈265,241 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈265,663 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈266,081 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈266,492 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈266,917 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈267,346 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈267,778 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈268,207 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈268,631 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈269,054 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈269,480 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈269,908 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈270,329 | recent=0.29 sec/artist | overall=0.32 sec/artist | save=0.00s
# Checkpoint saved: total≈270,761 | recent=0.28 sec/artist | overall=0.32 sec/artist | save=0.01s
# Checkpoint saved: total≈271,190 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈271,626 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈272,057 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈272,482 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈272,906 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈273,335 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈273,761 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈274,194 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈274,632 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈275,058 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈275,484 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈275,913 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈276,345 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈276,771 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈277,205 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈277,641 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈278,068 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈278,495 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈278,922 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈279,347 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈279,773 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈280,198 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈280,627 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈281,053 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈281,484 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈281,903 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈282,335 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈282,770 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈283,199 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈283,628 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈284,061 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈284,487 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈284,910 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈285,344 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈285,781 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈286,222 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈286,658 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈287,086 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈287,523 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈287,960 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈288,390 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈288,809 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈289,235 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈289,664 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈290,087 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈290,510 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈290,935 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈291,353 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈291,763 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈292,193 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈292,627 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈293,055 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈293,479 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈293,902 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈294,333 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈294,772 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈295,206 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈295,634 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈296,055 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈296,484 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈296,909 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈297,333 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈297,754 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈298,175 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈298,611 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈299,060 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈299,523 | recent=0.26 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈299,978 | recent=0.26 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈300,445 | recent=0.26 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈300,904 | recent=0.26 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈301,370 | recent=0.26 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈301,841 | recent=0.26 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈302,294 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈302,723 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈303,145 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈303,585 | recent=0.27 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈304,017 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈304,431 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈304,849 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈305,259 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈305,676 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈306,101 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.01s
# Checkpoint saved: total≈306,537 | recent=0.28 sec/artist | overall=0.31 sec/artist | save=0.00s
# Checkpoint saved: total≈306,952 | recent=0.29 sec/artist | overall=0.31 sec/artist | save=0.00s
# Saved 307,286 rows to artist_gender_lookup.csv
